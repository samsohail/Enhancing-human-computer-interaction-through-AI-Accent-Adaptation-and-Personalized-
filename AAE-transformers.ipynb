# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torchaudio
# !pip install transformers
# !pip install jiwer
# !pip install audiomentations
# Out:
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.4.0+cu121)
# Requirement already satisfied: torch==2.4.0 in /usr/local/lib/python3.10/dist-packages (from torchaudio) (2.4.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->torchaudio) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->torchaudio) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->torchaudio) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->torchaudio) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->torchaudio) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->torchaudio) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.4.0->torchaudio) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.4.0->torchaudio) (1.3.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.6)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Collecting jiwer
#   Downloading jiwer-3.0.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Downloading jiwer-3.0.4-py3-none-any.whl (21 kB)
# Downloading rapidfuzz-3.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 20.7 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.4 rapidfuzz-3.9.7
# Collecting audiomentations
#   Downloading audiomentations-0.37.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2,>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from audiomentations) (1.26.4)
# Collecting numpy-minmax<1,>=0.3.0 (from audiomentations)
#   Downloading numpy_minmax-0.3.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting numpy-rms<1,>=0.4.2 (from audiomentations)
#   Downloading numpy_rms-0.4.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: librosa!=0.10.0,<0.11.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from audiomentations) (0.10.2.post1)
# Collecting scipy<1.13,>=1.4 (from audiomentations)
#   Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: soxr<1.0.0,>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from audiomentations) (0.5.0.post1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (1.3.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (1.8.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (1.0.8)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from numpy-minmax<1,>=0.3.0->audiomentations) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.0->numpy-minmax<1,>=0.3.0->audiomentations) (2.22)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lazy-loader>=0.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (24.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (4.3.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (2.32.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations) (2024.8.30)
# Downloading audiomentations-0.37.0-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.5/80.5 kB 4.8 MB/s eta 0:00:00
# Downloading numpy_minmax-0.3.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Downloading numpy_rms-0.4.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17 kB)
# Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 14.5 MB/s eta 0:00:00
# Installing collected packages: scipy, numpy-rms, numpy-minmax, audiomentations
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# osqp 0.6.7.post0 requires scipy!=1.12.0,>=0.13.2, but you have scipy 1.12.0 which is incompatible.
# Successfully installed audiomentations-0.37.0 numpy-minmax-0.3.1 numpy-rms-0.4.2 scipy-1.12.0

# %%
import torch
import torchaudio
from torch.utils.data import Dataset, DataLoader
import os
from torch.nn import functional as F
import torch.nn as nn
import torch.optim as optim
import librosa
import numpy as np
from scipy.io.wavfile import write
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift
import matplotlib.pyplot as plt
import librosa.display
from jiwer import wer

# Step 1: Define Data Augmentation Pipeline
augment = Compose([
    AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.015, p=0.5),
    TimeStretch(min_rate=0.8, max_rate=1.25, p=0.5),
    PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
    Shift(min_shift=-0.5, max_shift=0.5, p=0.5)
])

# Custom Dataset for Loading Audio Files with Augmentation
class SpeechDataset(Dataset):
    def __init__(self, data_dir, transform=None, target_length=80000, num_files=100, apply_augmentation=False):
        self.data_dir = data_dir
        self.transform = transform
        self.target_length = target_length
        self.apply_augmentation = apply_augmentation
        self.audio_files = [f for f in os.listdir(data_dir) if f.endswith('.wav')][:num_files]

        if len(self.audio_files) == 0:
            raise ValueError(f"No audio files found in directory: {data_dir}")

    def __len__(self):
        return len(self.audio_files)

    def __getitem__(self, idx):
        wav_path = os.path.join(self.data_dir, self.audio_files[idx])
        if not os.path.exists(wav_path):
            raise FileNotFoundError(f"Audio file not found: {wav_path}")

        try:
            waveform, sr = torchaudio.load(wav_path)
        except RuntimeError as e:
            print(f"Error loading audio file: {wav_path}, Error: {e}")
            raise e

        # Pad or truncate to the target length
        if waveform.shape[1] < self.target_length:
            padding = self.target_length - waveform.shape[1]
            waveform = F.pad(waveform, (0, padding))
        else:
            waveform = waveform[:, :self.target_length]

        # Apply Augmentation
        if self.apply_augmentation:
            waveform = augment_audio(waveform)

        # Apply normalization if any
        if self.transform:
            waveform = self.transform(waveform)

        return waveform, self.audio_files[idx]

# Function to Apply Augmentation to the Audio
def augment_audio(audio):
    augmented_samples = augment(samples=audio.numpy(), sample_rate=16000)
    return torch.tensor(augmented_samples)

# Define Normalization Transform
def normalize_waveform(waveform):
    return (waveform - waveform.mean()) / waveform.std()

# Directories for Data
data_dir_A = "/content/drive/MyDrive/data/extracted_files-3/en/North_American_English_W/"

# Target length for all audio files
target_length = 80000

# Initialize Dataset with 550 Files and Apply Augmentation
dataset_A = SpeechDataset(data_dir_A, transform=normalize_waveform, target_length=target_length, num_files=100, apply_augmentation=True)

# Initialize DataLoader
dataloader_A = DataLoader(dataset_A, batch_size=1, shuffle=True)

# Define AAE Components with Transformer in Encoder
class TransformerEncoderLayer(nn.Module):
    def __init__(self, input_dim=80000, hidden_dim=512, n_heads=8, num_layers=2):
        super(TransformerEncoderLayer, self).__init__()

        # Project input to hidden_dim
        self.input_proj = nn.Linear(input_dim, hidden_dim)

        # Define a Transformer Encoder Layer
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=hidden_dim,  # Dimension of input features
            nhead=n_heads,       # Number of self-attention heads
            dim_feedforward=hidden_dim * 4,  # Feedforward network dimension
            activation='relu'    # Activation function
        )

        # Stack multiple Transformer Encoder Layers
        self.transformer_encoder = nn.TransformerEncoder(
            transformer_layer,
            num_layers=num_layers
        )

        # Project back to original dimension
        self.output_proj = nn.Linear(hidden_dim, 64)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten input
        x = self.input_proj(x)  # Project input to Transformer hidden dimension

        # Add a dummy sequence length dimension
        x = x.unsqueeze(1)  # Shape: (batch_size, seq_len=1, hidden_dim)

        # Pass through Transformer Encoder
        x = self.transformer_encoder(x)

        # Remove dummy sequence length dimension
        x = x.squeeze(1)  # Shape: (batch_size, hidden_dim)

        # Project back to lower dimension
        x = self.output_proj(x)  # Shape: (batch_size, 64)

        return x

class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()
        self.transformer = TransformerEncoderLayer()

    def forward(self, x):
        return self.transformer(x)

class Decoder(nn.Module):
    def __init__(self):
        super(Decoder, self).__init__()
        self.main = nn.Sequential(
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, 80000)
        )

    def forward(self, x):
        x = self.main(x)
        x = x.view(x.size(0), 1, -1)
        return x

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            nn.Linear(64, 32),
            nn.LeakyReLU(0.2),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.main(x)
        return x

# Initialize Models
encoder = Encoder()
decoder = Decoder()
discriminator = Discriminator()

# Initialize Loss Functions and Optimizers
criterion_reconstruction = nn.MSELoss()
criterion_adversarial = nn.BCELoss()
optimizer_enc_dec = optim.Adam(list(encoder.parameters()) + list(decoder.parameters()), lr=0.0002)
optimizer_disc = optim.Adam(discriminator.parameters(), lr=0.0002)

# Set device to GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

encoder.to(device)
decoder.to(device)
discriminator.to(device)

# Function to Compute MCD (Placeholder)
def compute_mcd(orig_audio, conv_audio):
    return np.random.random()

# Function to Plot Spectrograms
def plot_spectrogram(audio_path, title):
    y, sr = librosa.load(audio_path, sr=16000)
    plt.figure(figsize=(10, 4))
    D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
    librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar(format='%+2.0f dB')
    plt.title(title)
    plt.show()

# Evaluation function for Mean Mel-Cepstral Distortion (MCD) and WER
def evaluate_metrics(original_dir, converted_dir, mapping, asr_model, tokenizer):
    mcd_scores = []
    wer_scores = []

    for orig_file, conv_file in mapping.items():
        orig_path = os.path.join(original_dir, orig_file)
        conv_path = os.path.join(converted_dir, conv_file)

        if not os.path.exists(orig_path):
            print(f"Original file not found: {orig_path}")
            continue
        if not os.path.exists(conv_path):
            print(f"Converted file not found: {conv_path}")
            continue

        try:
            orig_audio, _ = torchaudio.load(orig_path)
            conv_audio, _ = torchaudio.load(conv_path)
        except RuntimeError as e:
            print(f"Error loading audio files. Original: {orig_path}, Converted: {conv_path}, Error: {e}")
            continue

        # Compute MCD
        mcd_score = compute_mcd(orig_audio, conv_audio)
        mcd_scores.append(mcd_score)

        # Plot Spectrograms for the first audio pair (Original and Converted)
        if len(mcd_scores) == 1:
            plot_spectrogram(orig_path, f"Original: {orig_file}")
            plot_spectrogram(conv_path, f"Converted: {conv_file}")

    if mcd_scores:
        mean_mcd = np.mean(mcd_scores)
        print(f"Mean MCD: {mean_mcd:.4f}")
    else:
        print("No valid scores computed due to missing or corrupt files.")

# Function to save audio data correctly
def save_audio(file_path, audio_tensor, sample_rate=16000):
    audio_np = audio_tensor.cpu().detach().numpy().squeeze(0)
    audio_np = audio_np / np.max(np.abs(audio_np) + 1e-6)
    audio_np = np.clip(audio_np, -1, 1)
    audio_np = (audio_np * 32767).astype(np.int16)

    if len(audio_np.shape) > 1:
        audio_np = audio_np[0]

    write(file_path, sample_rate, audio_np)

# Training Loop for AAE
def train_AAE(dataloader_A, num_epochs=5):
    filename_mapping_A = {}  # Mapping for evaluation

    for epoch in range(num_epochs):
        batch_count = 0
        for real_A, file_A in dataloader_A:
            real_A = real_A.to(device)
            batch_count += 1

            # Forward pass through Encoder and Decoder
            latent = encoder(real_A)
            reconstructed_A = decoder(latent)

            # Compute Reconstruction Loss
            loss_reconstruction = criterion_reconstruction(reconstructed_A, real_A)

            # Adversarial Loss
            optimizer_disc.zero_grad()
            true_labels = torch.ones(latent.size(0), 1).to(device)
            fake_labels = torch.zeros(latent.size(0), 1).to(device)

            # Train Discriminator
            loss_disc_real = criterion_adversarial(discriminator(latent.detach()), true_labels)
            fake_latent = torch.randn_like(latent).to(device)
            loss_disc_fake = criterion_adversarial(discriminator(fake_latent), fake_labels)
            loss_disc = (loss_disc_real + loss_disc_fake) / 2
            loss_disc.backward()
            optimizer_disc.step()

            # Train Encoder and Decoder with Adversarial Loss
            optimizer_enc_dec.zero_grad()
            loss_adv = criterion_adversarial(discriminator(latent), true_labels)
            loss_enc_dec = loss_reconstruction + loss_adv
            loss_enc_dec.backward()
            optimizer_enc_dec.step()

            # Save Converted Audio for Evaluation
            converted_A_path = f"/content/drive/MyDrive/data/extracted_files-3/en/aae_converted_epoch_{epoch}/{file_A[0]}"
            os.makedirs(os.path.dirname(converted_A_path), exist_ok=True)

            save_audio(converted_A_path, reconstructed_A, sample_rate=16000)

            # Update Mappings for Evaluation
            filename_mapping_A[file_A[0]] = file_A[0]  # Map original to new

            print(f"Epoch [{epoch+1}/{num_epochs}], Batch [{batch_count}], Loss D: {loss_disc.item():.4f}, Loss Enc-Dec: {loss_enc_dec.item():.4f}")

        print(f"Epoch [{epoch+1}/{num_epochs}] completed.")
        evaluate_aae(epoch, filename_mapping_A)

    print("Training completed successfully!")

# Evaluation function for AAE
def evaluate_aae(epoch, mapping_A):
    original_dir_A = "/content/drive/MyDrive/data/extracted_files-3/en/North_American_English_W/"
    converted_dir_A = f"/content/drive/MyDrive/data/extracted_files-3/en/aae_converted_epoch_{epoch}"

    print(f"Evaluating AAE performance after Epoch {epoch+1}")

    from transformers import Wav2Vec2ForCTC, Wav2Vec2Tokenizer

    # Load Wav2Vec2 model and tokenizer from HuggingFace
    asr_model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-large-960h")
    tokenizer = Wav2Vec2Tokenizer.from_pretrained("facebook/wav2vec2-large-960h")

    # Set the model to evaluation mode
    asr_model.eval()

    evaluate_metrics(original_dir=original_dir_A, converted_dir=converted_dir_A, mapping=mapping_A, asr_model=asr_model, tokenizer=tokenizer)

# Start Training for AAE
train_AAE(dataloader_A)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Epoch [1/5], Batch [1], Loss D: 0.8446, Loss Enc-Dec: 1.6379
# Epoch [1/5], Batch [2], Loss D: 0.7340, Loss Enc-Dec: 1.8349
# Epoch [1/5], Batch [3], Loss D: 0.5774, Loss Enc-Dec: 1.4327
# Epoch [1/5], Batch [4], Loss D: 0.5767, Loss Enc-Dec: 1.3329
# Epoch [1/5], Batch [5], Loss D: 0.6352, Loss Enc-Dec: 1.5683
# Epoch [1/5], Batch [6], Loss D: 0.8002, Loss Enc-Dec: 1.8265
# Epoch [1/5], Batch [7], Loss D: 0.6846, Loss Enc-Dec: 1.6601
# Epoch [1/5], Batch [8], Loss D: 0.4899, Loss Enc-Dec: 1.1846
# Epoch [1/5], Batch [9], Loss D: 0.5142, Loss Enc-Dec: 1.2964
# Epoch [1/5], Batch [10], Loss D: 0.5664, Loss Enc-Dec: 1.4460
# Epoch [1/5], Batch [11], Loss D: 0.5205, Loss Enc-Dec: 1.1913
# Epoch [1/5], Batch [12], Loss D: 0.5210, Loss Enc-Dec: 1.2298
# Epoch [1/5], Batch [13], Loss D: 0.4137, Loss Enc-Dec: 1.1873
# Epoch [1/5], Batch [14], Loss D: 0.5024, Loss Enc-Dec: 1.3424
# Epoch [1/5], Batch [15], Loss D: 0.5064, Loss Enc-Dec: 1.1411
# Epoch [1/5], Batch [16], Loss D: 0.4316, Loss Enc-Dec: 1.1959
# Epoch [1/5], Batch [17], Loss D: 0.4560, Loss Enc-Dec: 1.2534
# Epoch [1/5], Batch [18], Loss D: 0.3498, Loss Enc-Dec: 1.1344
# Epoch [1/5], Batch [19], Loss D: 0.4027, Loss Enc-Dec: 1.1331
# Epoch [1/5], Batch [20], Loss D: 0.3900, Loss Enc-Dec: 1.1526
# Epoch [1/5], Batch [21], Loss D: 0.4255, Loss Enc-Dec: 1.1270
# Epoch [1/5], Batch [22], Loss D: 0.4587, Loss Enc-Dec: 1.1155
# Epoch [1/5], Batch [23], Loss D: 0.3719, Loss Enc-Dec: 1.1011
# Epoch [1/5], Batch [24], Loss D: 0.4509, Loss Enc-Dec: 1.2035
# Epoch [1/5], Batch [25], Loss D: 0.3764, Loss Enc-Dec: 1.0988
# Epoch [1/5], Batch [26], Loss D: 0.4280, Loss Enc-Dec: 1.0884
# Epoch [1/5], Batch [27], Loss D: 0.5187, Loss Enc-Dec: 1.0958
# Epoch [1/5], Batch [28], Loss D: 0.3848, Loss Enc-Dec: 1.0859
# Epoch [1/5], Batch [29], Loss D: 0.4584, Loss Enc-Dec: 1.0815
# Epoch [1/5], Batch [30], Loss D: 0.5112, Loss Enc-Dec: 1.0718
# Epoch [1/5], Batch [31], Loss D: 0.3713, Loss Enc-Dec: 1.0861
# Epoch [1/5], Batch [32], Loss D: 0.4084, Loss Enc-Dec: 1.0762
# Epoch [1/5], Batch [33], Loss D: 0.4462, Loss Enc-Dec: 1.0612
# Epoch [1/5], Batch [34], Loss D: 0.3544, Loss Enc-Dec: 1.0605
# Epoch [1/5], Batch [35], Loss D: 0.4183, Loss Enc-Dec: 1.0556
# Epoch [1/5], Batch [36], Loss D: 0.4177, Loss Enc-Dec: 1.0522
# Epoch [1/5], Batch [37], Loss D: 0.3615, Loss Enc-Dec: 1.0647
# Epoch [1/5], Batch [38], Loss D: 0.3318, Loss Enc-Dec: 1.0510
# Epoch [1/5], Batch [39], Loss D: 0.4655, Loss Enc-Dec: 1.0456
# Epoch [1/5], Batch [40], Loss D: 0.3177, Loss Enc-Dec: 1.0460
# Epoch [1/5], Batch [41], Loss D: 0.4524, Loss Enc-Dec: 1.0445
# Epoch [1/5], Batch [42], Loss D: 0.3703, Loss Enc-Dec: 1.0415
# Epoch [1/5], Batch [43], Loss D: 0.3115, Loss Enc-Dec: 1.0478
# Epoch [1/5], Batch [44], Loss D: 0.4317, Loss Enc-Dec: 1.0376
# Epoch [1/5], Batch [45], Loss D: 0.3977, Loss Enc-Dec: 1.0399
# Epoch [1/5], Batch [46], Loss D: 0.3447, Loss Enc-Dec: 1.0341
# Epoch [1/5], Batch [47], Loss D: 0.4057, Loss Enc-Dec: 1.0419
# Epoch [1/5], Batch [48], Loss D: 0.3362, Loss Enc-Dec: 1.0304
# Epoch [1/5], Batch [49], Loss D: 0.3799, Loss Enc-Dec: 1.0300
# Epoch [1/5], Batch [50], Loss D: 0.3800, Loss Enc-Dec: 1.0404
# Epoch [1/5], Batch [51], Loss D: 0.4212, Loss Enc-Dec: 1.0299
# Epoch [1/5], Batch [52], Loss D: 0.4038, Loss Enc-Dec: 1.0294
# Epoch [1/5], Batch [53], Loss D: 0.3379, Loss Enc-Dec: 1.0257
# Epoch [1/5], Batch [54], Loss D: 0.3733, Loss Enc-Dec: 1.0286
# Epoch [1/5], Batch [55], Loss D: 0.4341, Loss Enc-Dec: 1.0244
# Epoch [1/5], Batch [56], Loss D: 0.3754, Loss Enc-Dec: 1.0230
# Epoch [1/5], Batch [57], Loss D: 0.4235, Loss Enc-Dec: 1.0222
# Epoch [1/5], Batch [58], Loss D: 0.3073, Loss Enc-Dec: 1.0233
# Epoch [1/5], Batch [59], Loss D: 0.4201, Loss Enc-Dec: 1.0206
# Epoch [1/5], Batch [60], Loss D: 0.3813, Loss Enc-Dec: 1.0205
# Epoch [1/5], Batch [61], Loss D: 0.3417, Loss Enc-Dec: 1.0194
# Epoch [1/5], Batch [62], Loss D: 0.2782, Loss Enc-Dec: 1.0188
# Epoch [1/5], Batch [63], Loss D: 0.3661, Loss Enc-Dec: 1.0185
# Epoch [1/5], Batch [64], Loss D: 0.3047, Loss Enc-Dec: 1.0176
# Epoch [1/5], Batch [65], Loss D: 0.3692, Loss Enc-Dec: 1.0191
# Epoch [1/5], Batch [66], Loss D: 0.2679, Loss Enc-Dec: 1.0173
# Epoch [1/5], Batch [67], Loss D: 0.4471, Loss Enc-Dec: 1.0178
# Epoch [1/5], Batch [68], Loss D: 0.4812, Loss Enc-Dec: 1.0156
# Epoch [1/5], Batch [69], Loss D: 0.3259, Loss Enc-Dec: 1.0153
# Epoch [1/5], Batch [70], Loss D: 0.3884, Loss Enc-Dec: 1.0159
# Epoch [1/5], Batch [71], Loss D: 0.3341, Loss Enc-Dec: 1.0161
# Epoch [1/5], Batch [72], Loss D: 0.3629, Loss Enc-Dec: 1.0159
# Epoch [1/5], Batch [73], Loss D: 0.3563, Loss Enc-Dec: 1.0151
# Epoch [1/5], Batch [74], Loss D: 0.4353, Loss Enc-Dec: 1.0140
# Epoch [1/5], Batch [75], Loss D: 0.3719, Loss Enc-Dec: 1.0135
# Epoch [1/5], Batch [76], Loss D: 0.4044, Loss Enc-Dec: 1.0142
# Epoch [1/5], Batch [77], Loss D: 0.3066, Loss Enc-Dec: 1.0145
# Epoch [1/5], Batch [78], Loss D: 0.3965, Loss Enc-Dec: 1.0127
# Epoch [1/5], Batch [79], Loss D: 0.2465, Loss Enc-Dec: 1.0130
# Epoch [1/5], Batch [80], Loss D: 0.4065, Loss Enc-Dec: 1.0135
# Epoch [1/5], Batch [81], Loss D: 0.3301, Loss Enc-Dec: 1.0124
# Epoch [1/5], Batch [82], Loss D: 0.3579, Loss Enc-Dec: 1.0138
# Epoch [1/5], Batch [83], Loss D: 0.3800, Loss Enc-Dec: 1.0132
# Epoch [1/5], Batch [84], Loss D: 0.3185, Loss Enc-Dec: 1.0129
# Epoch [1/5], Batch [85], Loss D: 0.3917, Loss Enc-Dec: 1.0117
# Epoch [1/5], Batch [86], Loss D: 0.3998, Loss Enc-Dec: 1.0160
# Epoch [1/5], Batch [87], Loss D: 0.4736, Loss Enc-Dec: 1.0113
# Epoch [1/5], Batch [88], Loss D: 0.3454, Loss Enc-Dec: 1.0125
# Epoch [1/5], Batch [89], Loss D: 0.3165, Loss Enc-Dec: 1.0111
# Epoch [1/5], Batch [90], Loss D: 0.3157, Loss Enc-Dec: 1.0114
# Epoch [1/5], Batch [91], Loss D: 0.2959, Loss Enc-Dec: 1.0097
# Epoch [1/5], Batch [92], Loss D: 0.4525, Loss Enc-Dec: 1.0107
# Epoch [1/5], Batch [93], Loss D: 0.4196, Loss Enc-Dec: 1.0106
# Epoch [1/5], Batch [94], Loss D: 0.2663, Loss Enc-Dec: 1.0098
# Epoch [1/5], Batch [95], Loss D: 0.3222, Loss Enc-Dec: 1.0101
# Epoch [1/5], Batch [96], Loss D: 0.3162, Loss Enc-Dec: 1.0090
# Epoch [1/5], Batch [97], Loss D: 0.3219, Loss Enc-Dec: 1.0098
# Epoch [1/5], Batch [98], Loss D: 0.3615, Loss Enc-Dec: 1.0099
# Epoch [1/5], Batch [99], Loss D: 0.3706, Loss Enc-Dec: 1.0090
# Epoch [1/5], Batch [100], Loss D: 0.3295, Loss Enc-Dec: 1.0095
# Epoch [1/5] completed.
# Evaluating AAE performance after Epoch 1
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/wav2vec2-large-960h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-960h and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/291 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Wav2Vec2CTCTokenizer'.
# The class this function is called from is 'Wav2Vec2Tokenizer'.
# /usr/local/lib/python3.10/dist-packages/transformers/models/wav2vec2/tokenization_wav2vec2.py:720: FutureWarning: The class `Wav2Vec2Tokenizer` is deprecated and will be removed in version 5 of Transformers. Please use `Wav2Vec2Processor` or `Wav2Vec2CTCTokenizer` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Mean MCD: 0.5227
# Epoch [2/5], Batch [1], Loss D: 0.3630, Loss Enc-Dec: 1.0098
# Epoch [2/5], Batch [2], Loss D: 0.2599, Loss Enc-Dec: 1.0097
# Epoch [2/5], Batch [3], Loss D: 0.3512, Loss Enc-Dec: 1.0092
# Epoch [2/5], Batch [4], Loss D: 0.3647, Loss Enc-Dec: 1.0102
# Epoch [2/5], Batch [5], Loss D: 0.3884, Loss Enc-Dec: 1.0091
# Epoch [2/5], Batch [6], Loss D: 0.2884, Loss Enc-Dec: 1.0089
# Epoch [2/5], Batch [7], Loss D: 0.3241, Loss Enc-Dec: 1.0087
# Epoch [2/5], Batch [8], Loss D: 0.4770, Loss Enc-Dec: 1.0086
# Epoch [2/5], Batch [9], Loss D: 0.3265, Loss Enc-Dec: 1.0092
# Epoch [2/5], Batch [10], Loss D: 0.3705, Loss Enc-Dec: 1.0084
# Epoch [2/5], Batch [11], Loss D: 0.3352, Loss Enc-Dec: 1.0084
# Epoch [2/5], Batch [12], Loss D: 0.2760, Loss Enc-Dec: 1.0080
# Epoch [2/5], Batch [13], Loss D: 0.3161, Loss Enc-Dec: 1.0082
# Epoch [2/5], Batch [14], Loss D: 0.4977, Loss Enc-Dec: 1.0075
# Epoch [2/5], Batch [15], Loss D: 0.4266, Loss Enc-Dec: 1.0084
# Epoch [2/5], Batch [16], Loss D: 0.3601, Loss Enc-Dec: 1.0075
# Epoch [2/5], Batch [17], Loss D: 0.3906, Loss Enc-Dec: 1.0080
# Epoch [2/5], Batch [18], Loss D: 0.2700, Loss Enc-Dec: 1.0076
# Epoch [2/5], Batch [19], Loss D: 0.3126, Loss Enc-Dec: 1.0076
# Epoch [2/5], Batch [20], Loss D: 0.4268, Loss Enc-Dec: 1.0079
# Epoch [2/5], Batch [21], Loss D: 0.3958, Loss Enc-Dec: 1.0080
# Epoch [2/5], Batch [22], Loss D: 0.3397, Loss Enc-Dec: 1.0080
# Epoch [2/5], Batch [23], Loss D: 0.4514, Loss Enc-Dec: 1.0076
# Epoch [2/5], Batch [24], Loss D: 0.3645, Loss Enc-Dec: 1.0079
# Epoch [2/5], Batch [25], Loss D: 0.3633, Loss Enc-Dec: 1.0088
# Epoch [2/5], Batch [26], Loss D: 0.4143, Loss Enc-Dec: 1.0071
# Epoch [2/5], Batch [27], Loss D: 0.3786, Loss Enc-Dec: 1.0084
# Epoch [2/5], Batch [28], Loss D: 0.3542, Loss Enc-Dec: 1.0077
# Epoch [2/5], Batch [29], Loss D: 0.3408, Loss Enc-Dec: 1.0076
# Epoch [2/5], Batch [30], Loss D: 0.3324, Loss Enc-Dec: 1.0087
# Epoch [2/5], Batch [31], Loss D: 0.3596, Loss Enc-Dec: 1.0072
# Epoch [2/5], Batch [32], Loss D: 0.3441, Loss Enc-Dec: 1.0074
# Epoch [2/5], Batch [33], Loss D: 0.3811, Loss Enc-Dec: 1.0074
# Epoch [2/5], Batch [34], Loss D: 0.3520, Loss Enc-Dec: 1.0074
# Epoch [2/5], Batch [35], Loss D: 0.3275, Loss Enc-Dec: 1.0070
# Epoch [2/5], Batch [36], Loss D: 0.3479, Loss Enc-Dec: 1.0077
# Epoch [2/5], Batch [37], Loss D: 0.3880, Loss Enc-Dec: 1.0077
# Epoch [2/5], Batch [38], Loss D: 0.3576, Loss Enc-Dec: 1.0072
# Epoch [2/5], Batch [39], Loss D: 0.3988, Loss Enc-Dec: 1.0072
# Epoch [2/5], Batch [40], Loss D: 0.2689, Loss Enc-Dec: 1.0079
# Epoch [2/5], Batch [41], Loss D: 0.3812, Loss Enc-Dec: 1.0072
# Epoch [2/5], Batch [42], Loss D: 0.4465, Loss Enc-Dec: 1.0070
# Epoch [2/5], Batch [43], Loss D: 0.3278, Loss Enc-Dec: 1.0064
# Epoch [2/5], Batch [44], Loss D: 0.3415, Loss Enc-Dec: 1.0075
# Epoch [2/5], Batch [45], Loss D: 0.4148, Loss Enc-Dec: 1.0076
# Epoch [2/5], Batch [46], Loss D: 0.3767, Loss Enc-Dec: 1.0069
# Epoch [2/5], Batch [47], Loss D: 0.2614, Loss Enc-Dec: 1.0067
# Epoch [2/5], Batch [48], Loss D: 0.3721, Loss Enc-Dec: 1.0068
# Epoch [2/5], Batch [49], Loss D: 0.2873, Loss Enc-Dec: 1.0073
# Epoch [2/5], Batch [50], Loss D: 0.4252, Loss Enc-Dec: 1.0068
# Epoch [2/5], Batch [51], Loss D: 0.3098, Loss Enc-Dec: 1.0064
# Epoch [2/5], Batch [52], Loss D: 0.3712, Loss Enc-Dec: 1.0072
# Epoch [2/5], Batch [53], Loss D: 0.3774, Loss Enc-Dec: 1.0063
# Epoch [2/5], Batch [54], Loss D: 0.4123, Loss Enc-Dec: 1.0062
# Epoch [2/5], Batch [55], Loss D: 0.2531, Loss Enc-Dec: 1.0071
# Epoch [2/5], Batch [56], Loss D: 0.3559, Loss Enc-Dec: 1.0066
# Epoch [2/5], Batch [57], Loss D: 0.3249, Loss Enc-Dec: 1.0075
# Epoch [2/5], Batch [58], Loss D: 0.3079, Loss Enc-Dec: 1.0063
# Epoch [2/5], Batch [59], Loss D: 0.4177, Loss Enc-Dec: 1.0067
# Epoch [2/5], Batch [60], Loss D: 0.3350, Loss Enc-Dec: 1.0070
# Epoch [2/5], Batch [61], Loss D: 0.3555, Loss Enc-Dec: 1.0064
# Epoch [2/5], Batch [62], Loss D: 0.3441, Loss Enc-Dec: 1.0064
# Epoch [2/5], Batch [63], Loss D: 0.3191, Loss Enc-Dec: 1.0067
# Epoch [2/5], Batch [64], Loss D: 0.3352, Loss Enc-Dec: 1.0073
# Epoch [2/5], Batch [65], Loss D: 0.3284, Loss Enc-Dec: 1.0065
# Epoch [2/5], Batch [66], Loss D: 0.4348, Loss Enc-Dec: 1.0067
# Epoch [2/5], Batch [67], Loss D: 0.2874, Loss Enc-Dec: 1.0065
# Epoch [2/5], Batch [68], Loss D: 0.2974, Loss Enc-Dec: 1.0064
# Epoch [2/5], Batch [69], Loss D: 0.2710, Loss Enc-Dec: 1.0056
# Epoch [2/5], Batch [70], Loss D: 0.2780, Loss Enc-Dec: 1.0063
# Epoch [2/5], Batch [71], Loss D: 0.3033, Loss Enc-Dec: 1.0063
# Epoch [2/5], Batch [72], Loss D: 0.3363, Loss Enc-Dec: 1.0054
# Epoch [2/5], Batch [73], Loss D: 0.2284, Loss Enc-Dec: 1.0060
# Epoch [2/5], Batch [74], Loss D: 0.3222, Loss Enc-Dec: 1.0060
# Epoch [2/5], Batch [75], Loss D: 0.2877, Loss Enc-Dec: 1.0054
# Epoch [2/5], Batch [76], Loss D: 0.3397, Loss Enc-Dec: 1.0068
# Epoch [2/5], Batch [77], Loss D: 0.3368, Loss Enc-Dec: 1.0054
# Epoch [2/5], Batch [78], Loss D: 0.3292, Loss Enc-Dec: 1.0057
# Epoch [2/5], Batch [79], Loss D: 0.2518, Loss Enc-Dec: 1.0061
# Epoch [2/5], Batch [80], Loss D: 0.3998, Loss Enc-Dec: 1.0063
# Epoch [2/5], Batch [81], Loss D: 0.3036, Loss Enc-Dec: 1.0055
# Epoch [2/5], Batch [82], Loss D: 0.3694, Loss Enc-Dec: 1.0057
# Epoch [2/5], Batch [83], Loss D: 0.3346, Loss Enc-Dec: 1.0058
# Epoch [2/5], Batch [84], Loss D: 0.3588, Loss Enc-Dec: 1.0051
# Epoch [2/5], Batch [85], Loss D: 0.3438, Loss Enc-Dec: 1.0053
# Epoch [2/5], Batch [86], Loss D: 0.3720, Loss Enc-Dec: 1.0056
# Epoch [2/5], Batch [87], Loss D: 0.2994, Loss Enc-Dec: 1.0054
# Epoch [2/5], Batch [88], Loss D: 0.3487, Loss Enc-Dec: 1.0052
# Epoch [2/5], Batch [89], Loss D: 0.2770, Loss Enc-Dec: 1.0054
# Epoch [2/5], Batch [90], Loss D: 0.3606, Loss Enc-Dec: 1.0057
# Epoch [2/5], Batch [91], Loss D: 0.2175, Loss Enc-Dec: 1.0060
# Epoch [2/5], Batch [92], Loss D: 0.3678, Loss Enc-Dec: 1.0054
# Epoch [2/5], Batch [93], Loss D: 0.3174, Loss Enc-Dec: 1.0049
# Epoch [2/5], Batch [94], Loss D: 0.3008, Loss Enc-Dec: 1.0049
# Epoch [2/5], Batch [95], Loss D: 0.3508, Loss Enc-Dec: 1.0059
# Epoch [2/5], Batch [96], Loss D: 0.3876, Loss Enc-Dec: 1.0058
# Epoch [2/5], Batch [97], Loss D: 0.4636, Loss Enc-Dec: 1.0046
# Epoch [2/5], Batch [98], Loss D: 0.2702, Loss Enc-Dec: 1.0059
# Epoch [2/5], Batch [99], Loss D: 0.2600, Loss Enc-Dec: 1.0056
# Epoch [2/5], Batch [100], Loss D: 0.3414, Loss Enc-Dec: 1.0055
# Epoch [2/5] completed.
# Evaluating AAE performance after Epoch 2
# Some weights of the model checkpoint at facebook/wav2vec2-large-960h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-960h and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Wav2Vec2CTCTokenizer'.
# The class this function is called from is 'Wav2Vec2Tokenizer'.
# /usr/local/lib/python3.10/dist-packages/transformers/models/wav2vec2/tokenization_wav2vec2.py:720: FutureWarning: The class `Wav2Vec2Tokenizer` is deprecated and will be removed in version 5 of Transformers. Please use `Wav2Vec2Processor` or `Wav2Vec2CTCTokenizer` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Mean MCD: 0.4704
# Epoch [3/5], Batch [1], Loss D: 0.3413, Loss Enc-Dec: 1.0054
# Epoch [3/5], Batch [2], Loss D: 0.2958, Loss Enc-Dec: 1.0045
# Epoch [3/5], Batch [3], Loss D: 0.3322, Loss Enc-Dec: 1.0052
# Epoch [3/5], Batch [4], Loss D: 0.2791, Loss Enc-Dec: 1.0050
# Epoch [3/5], Batch [5], Loss D: 0.4458, Loss Enc-Dec: 1.0049
# Epoch [3/5], Batch [6], Loss D: 0.3217, Loss Enc-Dec: 1.0048
# Epoch [3/5], Batch [7], Loss D: 0.3456, Loss Enc-Dec: 1.0055
# Epoch [3/5], Batch [8], Loss D: 0.3178, Loss Enc-Dec: 1.0053
# Epoch [3/5], Batch [9], Loss D: 0.2813, Loss Enc-Dec: 1.0049
# Epoch [3/5], Batch [10], Loss D: 0.3483, Loss Enc-Dec: 1.0053
# Epoch [3/5], Batch [11], Loss D: 0.3504, Loss Enc-Dec: 1.0050
# Epoch [3/5], Batch [12], Loss D: 0.3341, Loss Enc-Dec: 1.0053
# Epoch [3/5], Batch [13], Loss D: 0.3166, Loss Enc-Dec: 1.0057
# Epoch [3/5], Batch [14], Loss D: 0.2942, Loss Enc-Dec: 1.0048
# Epoch [3/5], Batch [15], Loss D: 0.3450, Loss Enc-Dec: 1.0048
# Epoch [3/5], Batch [16], Loss D: 0.3821, Loss Enc-Dec: 1.0055
# Epoch [3/5], Batch [17], Loss D: 0.2680, Loss Enc-Dec: 1.0050
# Epoch [3/5], Batch [18], Loss D: 0.4061, Loss Enc-Dec: 1.0046
# Epoch [3/5], Batch [19], Loss D: 0.3138, Loss Enc-Dec: 1.0051
# Epoch [3/5], Batch [20], Loss D: 0.2810, Loss Enc-Dec: 1.0049
# Epoch [3/5], Batch [21], Loss D: 0.3287, Loss Enc-Dec: 1.0050
# Epoch [3/5], Batch [22], Loss D: 0.3058, Loss Enc-Dec: 1.0054
# Epoch [3/5], Batch [23], Loss D: 0.3478, Loss Enc-Dec: 1.0053
# Epoch [3/5], Batch [24], Loss D: 0.3290, Loss Enc-Dec: 1.0047
# Epoch [3/5], Batch [25], Loss D: 0.2966, Loss Enc-Dec: 1.0051
# Epoch [3/5], Batch [26], Loss D: 0.3175, Loss Enc-Dec: 1.0045
# Epoch [3/5], Batch [27], Loss D: 0.3043, Loss Enc-Dec: 1.0052
# Epoch [3/5], Batch [28], Loss D: 0.3123, Loss Enc-Dec: 1.0053
# Epoch [3/5], Batch [29], Loss D: 0.4717, Loss Enc-Dec: 1.0053
# Epoch [3/5], Batch [30], Loss D: 0.2866, Loss Enc-Dec: 1.0051
# Epoch [3/5], Batch [31], Loss D: 0.2445, Loss Enc-Dec: 1.0050
# Epoch [3/5], Batch [32], Loss D: 0.4071, Loss Enc-Dec: 1.0051
# Epoch [3/5], Batch [33], Loss D: 0.3184, Loss Enc-Dec: 1.0053
# Epoch [3/5], Batch [34], Loss D: 0.1961, Loss Enc-Dec: 1.0050
# Epoch [3/5], Batch [35], Loss D: 0.2838, Loss Enc-Dec: 1.0048
# Epoch [3/5], Batch [36], Loss D: 0.3340, Loss Enc-Dec: 1.0053
# Epoch [3/5], Batch [37], Loss D: 0.4081, Loss Enc-Dec: 1.0047
# Epoch [3/5], Batch [38], Loss D: 0.2982, Loss Enc-Dec: 1.0050
# Epoch [3/5], Batch [39], Loss D: 0.3146, Loss Enc-Dec: 1.0046
# Epoch [3/5], Batch [40], Loss D: 0.3330, Loss Enc-Dec: 1.0055
# Epoch [3/5], Batch [41], Loss D: 0.3405, Loss Enc-Dec: 1.0050
# Epoch [3/5], Batch [42], Loss D: 0.3534, Loss Enc-Dec: 1.0047
# Epoch [3/5], Batch [43], Loss D: 0.3694, Loss Enc-Dec: 1.0051
# Epoch [3/5], Batch [44], Loss D: 0.3986, Loss Enc-Dec: 1.0044
# Epoch [3/5], Batch [45], Loss D: 0.3543, Loss Enc-Dec: 1.0046
# Epoch [3/5], Batch [46], Loss D: 0.3806, Loss Enc-Dec: 1.0049
# Epoch [3/5], Batch [47], Loss D: 0.3197, Loss Enc-Dec: 1.0044
# Epoch [3/5], Batch [48], Loss D: 0.3101, Loss Enc-Dec: 1.0046
# Epoch [3/5], Batch [49], Loss D: 0.3185, Loss Enc-Dec: 1.0050
# Epoch [3/5], Batch [50], Loss D: 0.3380, Loss Enc-Dec: 1.0049
# Epoch [3/5], Batch [51], Loss D: 0.3011, Loss Enc-Dec: 1.0040
# Epoch [3/5], Batch [52], Loss D: 0.2112, Loss Enc-Dec: 1.0042
# Epoch [3/5], Batch [53], Loss D: 0.3538, Loss Enc-Dec: 1.0049
# Epoch [3/5], Batch [54], Loss D: 0.2535, Loss Enc-Dec: 1.0050
# Epoch [3/5], Batch [55], Loss D: 0.3475, Loss Enc-Dec: 1.0048
# Epoch [3/5], Batch [56], Loss D: 0.2704, Loss Enc-Dec: 1.0053
# Epoch [3/5], Batch [57], Loss D: 0.4500, Loss Enc-Dec: 1.0050
# Epoch [3/5], Batch [58], Loss D: 0.3518, Loss Enc-Dec: 1.0040
# Epoch [3/5], Batch [59], Loss D: 0.3051, Loss Enc-Dec: 1.0044
# Epoch [3/5], Batch [60], Loss D: 0.4089, Loss Enc-Dec: 1.0049
# Epoch [3/5], Batch [61], Loss D: 0.4225, Loss Enc-Dec: 1.0046
# Epoch [3/5], Batch [62], Loss D: 0.3818, Loss Enc-Dec: 1.0052
# Epoch [3/5], Batch [63], Loss D: 0.3526, Loss Enc-Dec: 1.0044
# Epoch [3/5], Batch [64], Loss D: 0.2764, Loss Enc-Dec: 1.0044
# Epoch [3/5], Batch [65], Loss D: 0.3075, Loss Enc-Dec: 1.0046
# Epoch [3/5], Batch [66], Loss D: 0.3038, Loss Enc-Dec: 1.0046
# Epoch [3/5], Batch [67], Loss D: 0.3017, Loss Enc-Dec: 1.0058
# Epoch [3/5], Batch [68], Loss D: 0.2483, Loss Enc-Dec: 1.0045
# Epoch [3/5], Batch [69], Loss D: 0.3617, Loss Enc-Dec: 1.0050
# Epoch [3/5], Batch [70], Loss D: 0.2907, Loss Enc-Dec: 1.0044
# Epoch [3/5], Batch [71], Loss D: 0.2885, Loss Enc-Dec: 1.0045
# Epoch [3/5], Batch [72], Loss D: 0.3359, Loss Enc-Dec: 1.0043
# Epoch [3/5], Batch [73], Loss D: 0.2671, Loss Enc-Dec: 1.0051
# Epoch [3/5], Batch [74], Loss D: 0.2310, Loss Enc-Dec: 1.0044
# Epoch [3/5], Batch [75], Loss D: 0.3383, Loss Enc-Dec: 1.0043
# Epoch [3/5], Batch [76], Loss D: 0.3130, Loss Enc-Dec: 1.0053
# Epoch [3/5], Batch [77], Loss D: 0.2806, Loss Enc-Dec: 1.0047
# Epoch [3/5], Batch [78], Loss D: 0.1920, Loss Enc-Dec: 1.0041
# Epoch [3/5], Batch [79], Loss D: 0.3335, Loss Enc-Dec: 1.0049
# Epoch [3/5], Batch [80], Loss D: 0.2993, Loss Enc-Dec: 1.0042
# Epoch [3/5], Batch [81], Loss D: 0.2396, Loss Enc-Dec: 1.0042
# Epoch [3/5], Batch [82], Loss D: 0.3406, Loss Enc-Dec: 1.0048
# Epoch [3/5], Batch [83], Loss D: 0.3352, Loss Enc-Dec: 1.0043
# Epoch [3/5], Batch [84], Loss D: 0.3526, Loss Enc-Dec: 1.0045
# Epoch [3/5], Batch [85], Loss D: 0.2726, Loss Enc-Dec: 1.0050
# Epoch [3/5], Batch [86], Loss D: 0.3652, Loss Enc-Dec: 1.0042
# Epoch [3/5], Batch [87], Loss D: 0.3382, Loss Enc-Dec: 1.0047
# Epoch [3/5], Batch [88], Loss D: 0.3610, Loss Enc-Dec: 1.0043
# Epoch [3/5], Batch [89], Loss D: 0.3005, Loss Enc-Dec: 1.0044
# Epoch [3/5], Batch [90], Loss D: 0.2278, Loss Enc-Dec: 1.0044
# Epoch [3/5], Batch [91], Loss D: 0.3112, Loss Enc-Dec: 1.0050
# Epoch [3/5], Batch [92], Loss D: 0.3269, Loss Enc-Dec: 1.0039
# Epoch [3/5], Batch [93], Loss D: 0.3575, Loss Enc-Dec: 1.0045
# Epoch [3/5], Batch [94], Loss D: 0.3521, Loss Enc-Dec: 1.0042
# Epoch [3/5], Batch [95], Loss D: 0.2802, Loss Enc-Dec: 1.0040
# Epoch [3/5], Batch [96], Loss D: 0.2396, Loss Enc-Dec: 1.0046
# Epoch [3/5], Batch [97], Loss D: 0.2536, Loss Enc-Dec: 1.0041
# Epoch [3/5], Batch [98], Loss D: 0.2138, Loss Enc-Dec: 1.0038
# Epoch [3/5], Batch [99], Loss D: 0.2162, Loss Enc-Dec: 1.0044
# Epoch [3/5], Batch [100], Loss D: 0.3135, Loss Enc-Dec: 1.0047
# Epoch [3/5] completed.
# Evaluating AAE performance after Epoch 3
# Some weights of the model checkpoint at facebook/wav2vec2-large-960h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-960h and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Wav2Vec2CTCTokenizer'.
# The class this function is called from is 'Wav2Vec2Tokenizer'.
# Mean MCD: 0.5043
# Epoch [4/5], Batch [1], Loss D: 0.3629, Loss Enc-Dec: 1.0044
# Epoch [4/5], Batch [2], Loss D: 0.3928, Loss Enc-Dec: 1.0045
# Epoch [4/5], Batch [3], Loss D: 0.2978, Loss Enc-Dec: 1.0043
# Epoch [4/5], Batch [4], Loss D: 0.3785, Loss Enc-Dec: 1.0038
# Epoch [4/5], Batch [5], Loss D: 0.2458, Loss Enc-Dec: 1.0044
# Epoch [4/5], Batch [6], Loss D: 0.2214, Loss Enc-Dec: 1.0038
# Epoch [4/5], Batch [7], Loss D: 0.3250, Loss Enc-Dec: 1.0043
# Epoch [4/5], Batch [8], Loss D: 0.2538, Loss Enc-Dec: 1.0042
# Epoch [4/5], Batch [9], Loss D: 0.2942, Loss Enc-Dec: 1.0039
# Epoch [4/5], Batch [10], Loss D: 0.3420, Loss Enc-Dec: 1.0046
# Epoch [4/5], Batch [11], Loss D: 0.2595, Loss Enc-Dec: 1.0041
# Epoch [4/5], Batch [12], Loss D: 0.3209, Loss Enc-Dec: 1.0040
# Epoch [4/5], Batch [13], Loss D: 0.3456, Loss Enc-Dec: 1.0037
# Epoch [4/5], Batch [14], Loss D: 0.3318, Loss Enc-Dec: 1.0047
# Epoch [4/5], Batch [15], Loss D: 0.2753, Loss Enc-Dec: 1.0036
# Epoch [4/5], Batch [16], Loss D: 0.2999, Loss Enc-Dec: 1.0042
# Epoch [4/5], Batch [17], Loss D: 0.2188, Loss Enc-Dec: 1.0033
# Epoch [4/5], Batch [18], Loss D: 0.2794, Loss Enc-Dec: 1.0042
# Epoch [4/5], Batch [19], Loss D: 0.3219, Loss Enc-Dec: 1.0044
# Epoch [4/5], Batch [20], Loss D: 0.3592, Loss Enc-Dec: 1.0043
# Epoch [4/5], Batch [21], Loss D: 0.3612, Loss Enc-Dec: 1.0046
# Epoch [4/5], Batch [22], Loss D: 0.4219, Loss Enc-Dec: 1.0040
# Epoch [4/5], Batch [23], Loss D: 0.3027, Loss Enc-Dec: 1.0043
# Epoch [4/5], Batch [24], Loss D: 0.2583, Loss Enc-Dec: 1.0040
# Epoch [4/5], Batch [25], Loss D: 0.3512, Loss Enc-Dec: 1.0039
# Epoch [4/5], Batch [26], Loss D: 0.3243, Loss Enc-Dec: 1.0044
# Epoch [4/5], Batch [27], Loss D: 0.3193, Loss Enc-Dec: 1.0040
# Epoch [4/5], Batch [28], Loss D: 0.2744, Loss Enc-Dec: 1.0042
# Epoch [4/5], Batch [29], Loss D: 0.3311, Loss Enc-Dec: 1.0043
# Epoch [4/5], Batch [30], Loss D: 0.2739, Loss Enc-Dec: 1.0038
# Epoch [4/5], Batch [31], Loss D: 0.2727, Loss Enc-Dec: 1.0054
# Epoch [4/5], Batch [32], Loss D: 0.3044, Loss Enc-Dec: 1.0038
# Epoch [4/5], Batch [33], Loss D: 0.2803, Loss Enc-Dec: 1.0038
# Epoch [4/5], Batch [34], Loss D: 0.3205, Loss Enc-Dec: 1.0038
# Epoch [4/5], Batch [35], Loss D: 0.2648, Loss Enc-Dec: 1.0042
# Epoch [4/5], Batch [36], Loss D: 0.2924, Loss Enc-Dec: 1.0041
# Epoch [4/5], Batch [37], Loss D: 0.3151, Loss Enc-Dec: 1.0042
# Epoch [4/5], Batch [38], Loss D: 0.3357, Loss Enc-Dec: 1.0034
# Epoch [4/5], Batch [39], Loss D: 0.4175, Loss Enc-Dec: 1.0038
# Epoch [4/5], Batch [40], Loss D: 0.3484, Loss Enc-Dec: 1.0039
# Epoch [4/5], Batch [41], Loss D: 0.3082, Loss Enc-Dec: 1.0045
# Epoch [4/5], Batch [42], Loss D: 0.2723, Loss Enc-Dec: 1.0039
# Epoch [4/5], Batch [43], Loss D: 0.3135, Loss Enc-Dec: 1.0036
# Epoch [4/5], Batch [44], Loss D: 0.2665, Loss Enc-Dec: 1.0042
# Epoch [4/5], Batch [45], Loss D: 0.2590, Loss Enc-Dec: 1.0031
# Epoch [4/5], Batch [46], Loss D: 0.2728, Loss Enc-Dec: 1.0037
# Epoch [4/5], Batch [47], Loss D: 0.3253, Loss Enc-Dec: 1.0042
# Epoch [4/5], Batch [48], Loss D: 0.2600, Loss Enc-Dec: 1.0039
# Epoch [4/5], Batch [49], Loss D: 0.3795, Loss Enc-Dec: 1.0050
# Epoch [4/5], Batch [50], Loss D: 0.3106, Loss Enc-Dec: 1.0044
# Epoch [4/5], Batch [51], Loss D: 0.2600, Loss Enc-Dec: 1.0038
# Epoch [4/5], Batch [52], Loss D: 0.2346, Loss Enc-Dec: 1.0038
# Epoch [4/5], Batch [53], Loss D: 0.2963, Loss Enc-Dec: 1.0034
# Epoch [4/5], Batch [54], Loss D: 0.2568, Loss Enc-Dec: 1.0041
# Epoch [4/5], Batch [55], Loss D: 0.2950, Loss Enc-Dec: 1.0041
# Epoch [4/5], Batch [56], Loss D: 0.2167, Loss Enc-Dec: 1.0042
# Epoch [4/5], Batch [57], Loss D: 0.2782, Loss Enc-Dec: 1.0044
# Epoch [4/5], Batch [58], Loss D: 0.3054, Loss Enc-Dec: 1.0036
# Epoch [4/5], Batch [59], Loss D: 0.2874, Loss Enc-Dec: 1.0047
# Epoch [4/5], Batch [60], Loss D: 0.2969, Loss Enc-Dec: 1.0043
# Epoch [4/5], Batch [61], Loss D: 0.3082, Loss Enc-Dec: 1.0039
# Epoch [4/5], Batch [62], Loss D: 0.4479, Loss Enc-Dec: 1.0041
# Epoch [4/5], Batch [63], Loss D: 0.3457, Loss Enc-Dec: 1.0043
# Epoch [4/5], Batch [64], Loss D: 0.2356, Loss Enc-Dec: 1.0036
# Epoch [4/5], Batch [65], Loss D: 0.3174, Loss Enc-Dec: 1.0043
# Epoch [4/5], Batch [66], Loss D: 0.3998, Loss Enc-Dec: 1.0042
# Epoch [4/5], Batch [67], Loss D: 0.3206, Loss Enc-Dec: 1.0038
# Epoch [4/5], Batch [68], Loss D: 0.2570, Loss Enc-Dec: 1.0032
# Epoch [4/5], Batch [69], Loss D: 0.2835, Loss Enc-Dec: 1.0040
# Epoch [4/5], Batch [70], Loss D: 0.3082, Loss Enc-Dec: 1.0045
# Epoch [4/5], Batch [71], Loss D: 0.3322, Loss Enc-Dec: 1.0035
# Epoch [4/5], Batch [72], Loss D: 0.3441, Loss Enc-Dec: 1.0039
# Epoch [4/5], Batch [73], Loss D: 0.3555, Loss Enc-Dec: 1.0038
# Epoch [4/5], Batch [74], Loss D: 0.2930, Loss Enc-Dec: 1.0036
# Epoch [4/5], Batch [75], Loss D: 0.2669, Loss Enc-Dec: 1.0043
# Epoch [4/5], Batch [76], Loss D: 0.2877, Loss Enc-Dec: 1.0039
# Epoch [4/5], Batch [77], Loss D: 0.3799, Loss Enc-Dec: 1.0039
# Epoch [4/5], Batch [78], Loss D: 0.3313, Loss Enc-Dec: 1.0042
# Epoch [4/5], Batch [79], Loss D: 0.3011, Loss Enc-Dec: 1.0037
# Epoch [4/5], Batch [80], Loss D: 0.3230, Loss Enc-Dec: 1.0038
# Epoch [4/5], Batch [81], Loss D: 0.3403, Loss Enc-Dec: 1.0044
# Epoch [4/5], Batch [82], Loss D: 0.2616, Loss Enc-Dec: 1.0035
# Epoch [4/5], Batch [83], Loss D: 0.2075, Loss Enc-Dec: 1.0041
# Epoch [4/5], Batch [84], Loss D: 0.3125, Loss Enc-Dec: 1.0039
# Epoch [4/5], Batch [85], Loss D: 0.3239, Loss Enc-Dec: 1.0038
# Epoch [4/5], Batch [86], Loss D: 0.3072, Loss Enc-Dec: 1.0035
# Epoch [4/5], Batch [87], Loss D: 0.2208, Loss Enc-Dec: 1.0036
# Epoch [4/5], Batch [88], Loss D: 0.2993, Loss Enc-Dec: 1.0034
# Epoch [4/5], Batch [89], Loss D: 0.3244, Loss Enc-Dec: 1.0033
# Epoch [4/5], Batch [90], Loss D: 0.3010, Loss Enc-Dec: 1.0036
# Epoch [4/5], Batch [91], Loss D: 0.2347, Loss Enc-Dec: 1.0035
# Epoch [4/5], Batch [92], Loss D: 0.2862, Loss Enc-Dec: 1.0044
# Epoch [4/5], Batch [93], Loss D: 0.2659, Loss Enc-Dec: 1.0035
# Epoch [4/5], Batch [94], Loss D: 0.2691, Loss Enc-Dec: 1.0042
# Epoch [4/5], Batch [95], Loss D: 0.2705, Loss Enc-Dec: 1.0036
# Epoch [4/5], Batch [96], Loss D: 0.2720, Loss Enc-Dec: 1.0044
# Epoch [4/5], Batch [97], Loss D: 0.2873, Loss Enc-Dec: 1.0036
# Epoch [4/5], Batch [98], Loss D: 0.2284, Loss Enc-Dec: 1.0032
# Epoch [4/5], Batch [99], Loss D: 0.3045, Loss Enc-Dec: 1.0041
# Epoch [4/5], Batch [100], Loss D: 0.2108, Loss Enc-Dec: 1.0040
# Epoch [4/5] completed.
# Evaluating AAE performance after Epoch 4
# Some weights of the model checkpoint at facebook/wav2vec2-large-960h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-960h and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Wav2Vec2CTCTokenizer'.
# The class this function is called from is 'Wav2Vec2Tokenizer'.
# Mean MCD: 0.5630
# Epoch [5/5], Batch [1], Loss D: 0.2256, Loss Enc-Dec: 1.0040
# Epoch [5/5], Batch [2], Loss D: 0.2459, Loss Enc-Dec: 1.0040
# Epoch [5/5], Batch [3], Loss D: 0.2910, Loss Enc-Dec: 1.0042
# Epoch [5/5], Batch [4], Loss D: 0.2566, Loss Enc-Dec: 1.0041
# Epoch [5/5], Batch [5], Loss D: 0.2701, Loss Enc-Dec: 1.0035
# Epoch [5/5], Batch [6], Loss D: 0.2294, Loss Enc-Dec: 1.0034
# Epoch [5/5], Batch [7], Loss D: 0.2696, Loss Enc-Dec: 1.0039
# Epoch [5/5], Batch [8], Loss D: 0.3517, Loss Enc-Dec: 1.0039
# Epoch [5/5], Batch [9], Loss D: 0.2121, Loss Enc-Dec: 1.0038
# Epoch [5/5], Batch [10], Loss D: 0.2875, Loss Enc-Dec: 1.0036
# Epoch [5/5], Batch [11], Loss D: 0.2836, Loss Enc-Dec: 1.0035
# Epoch [5/5], Batch [12], Loss D: 0.3072, Loss Enc-Dec: 1.0032
# Epoch [5/5], Batch [13], Loss D: 0.2803, Loss Enc-Dec: 1.0036
# Epoch [5/5], Batch [14], Loss D: 0.2880, Loss Enc-Dec: 1.0035
# Epoch [5/5], Batch [15], Loss D: 0.2521, Loss Enc-Dec: 1.0036
# Epoch [5/5], Batch [16], Loss D: 0.1887, Loss Enc-Dec: 1.0037
# Epoch [5/5], Batch [17], Loss D: 0.2903, Loss Enc-Dec: 1.0043
# Epoch [5/5], Batch [18], Loss D: 0.1929, Loss Enc-Dec: 1.0039
# Epoch [5/5], Batch [19], Loss D: 0.2733, Loss Enc-Dec: 1.0035
# Epoch [5/5], Batch [20], Loss D: 0.3046, Loss Enc-Dec: 1.0041
# Epoch [5/5], Batch [21], Loss D: 0.1309, Loss Enc-Dec: 1.0039
# Epoch [5/5], Batch [22], Loss D: 0.2119, Loss Enc-Dec: 1.0035
# Epoch [5/5], Batch [23], Loss D: 0.2876, Loss Enc-Dec: 1.0040
# Epoch [5/5], Batch [24], Loss D: 0.2634, Loss Enc-Dec: 1.0038
# Epoch [5/5], Batch [25], Loss D: 0.2135, Loss Enc-Dec: 1.0037
# Epoch [5/5], Batch [26], Loss D: 0.2330, Loss Enc-Dec: 1.0032
# Epoch [5/5], Batch [27], Loss D: 0.2381, Loss Enc-Dec: 1.0035
# Epoch [5/5], Batch [28], Loss D: 0.1860, Loss Enc-Dec: 1.0030
# Epoch [5/5], Batch [29], Loss D: 0.2803, Loss Enc-Dec: 1.0033
# Epoch [5/5], Batch [30], Loss D: 0.3361, Loss Enc-Dec: 1.0035
# Epoch [5/5], Batch [31], Loss D: 0.3078, Loss Enc-Dec: 1.0033
# Epoch [5/5], Batch [32], Loss D: 0.3126, Loss Enc-Dec: 1.0031
# Epoch [5/5], Batch [33], Loss D: 0.3092, Loss Enc-Dec: 1.0037
# Epoch [5/5], Batch [34], Loss D: 0.3508, Loss Enc-Dec: 1.0036
# Epoch [5/5], Batch [35], Loss D: 0.2932, Loss Enc-Dec: 1.0028
# Epoch [5/5], Batch [36], Loss D: 0.2792, Loss Enc-Dec: 1.0037
# Epoch [5/5], Batch [37], Loss D: 0.2875, Loss Enc-Dec: 1.0036
# Epoch [5/5], Batch [38], Loss D: 0.3093, Loss Enc-Dec: 1.0034
# Epoch [5/5], Batch [39], Loss D: 0.3396, Loss Enc-Dec: 1.0031
# Epoch [5/5], Batch [40], Loss D: 0.2267, Loss Enc-Dec: 1.0035
# Epoch [5/5], Batch [41], Loss D: 0.2646, Loss Enc-Dec: 1.0032
# Epoch [5/5], Batch [42], Loss D: 0.2009, Loss Enc-Dec: 1.0035
# Epoch [5/5], Batch [43], Loss D: 0.2291, Loss Enc-Dec: 1.0040
# Epoch [5/5], Batch [44], Loss D: 0.3631, Loss Enc-Dec: 1.0038
# Epoch [5/5], Batch [45], Loss D: 0.1715, Loss Enc-Dec: 1.0032
# Epoch [5/5], Batch [46], Loss D: 0.2467, Loss Enc-Dec: 1.0031
# Epoch [5/5], Batch [47], Loss D: 0.2308, Loss Enc-Dec: 1.0031
# Epoch [5/5], Batch [48], Loss D: 0.2526, Loss Enc-Dec: 1.0034
# Epoch [5/5], Batch [49], Loss D: 0.2552, Loss Enc-Dec: 1.0037
# Epoch [5/5], Batch [50], Loss D: 0.3369, Loss Enc-Dec: 1.0036
# Epoch [5/5], Batch [51], Loss D: 0.2120, Loss Enc-Dec: 1.0036
# Epoch [5/5], Batch [52], Loss D: 0.2991, Loss Enc-Dec: 1.0033
# Epoch [5/5], Batch [53], Loss D: 0.2797, Loss Enc-Dec: 1.0029
# Epoch [5/5], Batch [54], Loss D: 0.3186, Loss Enc-Dec: 1.0033
# Epoch [5/5], Batch [55], Loss D: 0.2484, Loss Enc-Dec: 1.0030
# Epoch [5/5], Batch [56], Loss D: 0.3253, Loss Enc-Dec: 1.0034
# Epoch [5/5], Batch [57], Loss D: 0.1998, Loss Enc-Dec: 1.0031
# Epoch [5/5], Batch [58], Loss D: 0.1641, Loss Enc-Dec: 1.0035
# Epoch [5/5], Batch [59], Loss D: 0.2361, Loss Enc-Dec: 1.0033
# Epoch [5/5], Batch [60], Loss D: 0.3466, Loss Enc-Dec: 1.0030
# Epoch [5/5], Batch [61], Loss D: 0.3053, Loss Enc-Dec: 1.0034
# Epoch [5/5], Batch [62], Loss D: 0.2749, Loss Enc-Dec: 1.0036
# Epoch [5/5], Batch [63], Loss D: 0.3172, Loss Enc-Dec: 1.0031
# Epoch [5/5], Batch [64], Loss D: 0.2619, Loss Enc-Dec: 1.0036
# Epoch [5/5], Batch [65], Loss D: 0.3077, Loss Enc-Dec: 1.0039
# Epoch [5/5], Batch [66], Loss D: 0.2724, Loss Enc-Dec: 1.0036
# Epoch [5/5], Batch [67], Loss D: 0.3003, Loss Enc-Dec: 1.0033
# Epoch [5/5], Batch [68], Loss D: 0.2202, Loss Enc-Dec: 1.0037
# Epoch [5/5], Batch [69], Loss D: 0.3120, Loss Enc-Dec: 1.0026
# Epoch [5/5], Batch [70], Loss D: 0.2525, Loss Enc-Dec: 1.0033
# Epoch [5/5], Batch [71], Loss D: 0.1645, Loss Enc-Dec: 1.0032
# Epoch [5/5], Batch [72], Loss D: 0.2284, Loss Enc-Dec: 1.0031
# Epoch [5/5], Batch [73], Loss D: 0.3324, Loss Enc-Dec: 1.0030
# Epoch [5/5], Batch [74], Loss D: 0.2479, Loss Enc-Dec: 1.0030
# Epoch [5/5], Batch [75], Loss D: 0.3425, Loss Enc-Dec: 1.0039
# Epoch [5/5], Batch [76], Loss D: 0.1838, Loss Enc-Dec: 1.0032
# Epoch [5/5], Batch [77], Loss D: 0.2947, Loss Enc-Dec: 1.0033
# Epoch [5/5], Batch [78], Loss D: 0.1915, Loss Enc-Dec: 1.0032
# Epoch [5/5], Batch [79], Loss D: 0.2862, Loss Enc-Dec: 1.0041
# Epoch [5/5], Batch [80], Loss D: 0.2140, Loss Enc-Dec: 1.0034
# Epoch [5/5], Batch [81], Loss D: 0.3763, Loss Enc-Dec: 1.0031
# Epoch [5/5], Batch [82], Loss D: 0.2131, Loss Enc-Dec: 1.0039
# Epoch [5/5], Batch [83], Loss D: 0.2938, Loss Enc-Dec: 1.0027
# Epoch [5/5], Batch [84], Loss D: 0.3142, Loss Enc-Dec: 1.0036
# Epoch [5/5], Batch [85], Loss D: 0.2460, Loss Enc-Dec: 1.0031
# Epoch [5/5], Batch [86], Loss D: 0.3672, Loss Enc-Dec: 1.0028
# Epoch [5/5], Batch [87], Loss D: 0.2695, Loss Enc-Dec: 1.0032
# Epoch [5/5], Batch [88], Loss D: 0.2517, Loss Enc-Dec: 1.0033
# Epoch [5/5], Batch [89], Loss D: 0.2573, Loss Enc-Dec: 1.0032
# Epoch [5/5], Batch [90], Loss D: 0.2753, Loss Enc-Dec: 1.0030
# Epoch [5/5], Batch [91], Loss D: 0.3449, Loss Enc-Dec: 1.0028
# Epoch [5/5], Batch [92], Loss D: 0.2935, Loss Enc-Dec: 1.0041
# Epoch [5/5], Batch [93], Loss D: 0.2212, Loss Enc-Dec: 1.0035
# Epoch [5/5], Batch [94], Loss D: 0.2247, Loss Enc-Dec: 1.0028
# Epoch [5/5], Batch [95], Loss D: 0.2487, Loss Enc-Dec: 1.0035
# Epoch [5/5], Batch [96], Loss D: 0.2868, Loss Enc-Dec: 1.0032
# Epoch [5/5], Batch [97], Loss D: 0.2106, Loss Enc-Dec: 1.0035
# Epoch [5/5], Batch [98], Loss D: 0.2473, Loss Enc-Dec: 1.0036
# Epoch [5/5], Batch [99], Loss D: 0.2569, Loss Enc-Dec: 1.0030
# Epoch [5/5], Batch [100], Loss D: 0.2042, Loss Enc-Dec: 1.0033
# Epoch [5/5] completed.
# Evaluating AAE performance after Epoch 5
# Some weights of the model checkpoint at facebook/wav2vec2-large-960h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-960h and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Wav2Vec2CTCTokenizer'.
# The class this function is called from is 'Wav2Vec2Tokenizer'.
# Mean MCD: 0.4698
# Training completed successfully!
